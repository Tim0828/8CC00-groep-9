# %%
import pandas as pd

# %%
# reading the data: 
df_pca = pd.read_csv(r"C:\Users\20223319\OneDrive - TU Eindhoven\Bestanden\Jaar 2\Q4\Advanced Programming\Group Assignment\PCA_data.csv")
df_pca.head(5)
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -2.309637  0.110012 -0.167812  0.415622 -0.708685 -0.228996  0.489274
# 1 -1.480759  0.071782 -0.362192  0.134438  0.060655  0.418065 -0.170570
# 2 -1.339915 -0.732580 -0.292049 -0.000752 -0.335779 -0.633832  0.249674
# 3 -1.308999  0.064899 -0.297213  0.293515  0.022697 -0.197055 -0.325017
# 4 -1.689393  0.044651 -0.294212 -0.450916 -0.044918 -0.209571 -0.037206
#
#         PC8       PC9      PC10  ...      PC36      PC37      PC38      PC39  \
# 0  0.502488  0.275599  0.162080  ...  0.201244 -0.048362  0.098921  0.300486
# 1 -0.134406 -0.272860  0.036386  ...  0.096480  0.023146 -0.021690  0.215814
# 2 -0.172008  0.593940 -0.902144  ...  0.189647 -0.070936  0.059453  0.137679
# 3  0.276734 -0.198548 -0.193834  ...  0.047974  0.097950  0.104997  0.122059
# 4  0.018413 -0.407805 -0.437409  ...  0.149137  0.155742 -0.068676  0.146888
#
# ...

# %%
from sklearn.model_selection import train_test_split

# splitting the data into test and training data:
df_X = df_pca.drop(["PKM2_inhibition","ERK2_inhibition"],axis=1)
df_Y = df_pca[["PKM2_inhibition","ERK2_inhibition"]]

X_train, X_test, y_train, y_test = train_test_split(df_X, df_Y, train_size=0.8)

# %%
from sklearn.ensemble import RandomForestClassifier

# fitting data:
classifier = RandomForestClassifier(100)
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report

# predicting data and testing accuracy:
predict = classifier.predict(X_test)
score = classifier.score(X_test,y_test)
score
# Out:
# 0.9508928571428571
